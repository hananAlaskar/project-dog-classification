# %% [markdown]
# # Convolutional Neural Networks
#
# ## Project: Write an Algorithm for a Dog Identification App
#
# ---
#
# In this notebook, some template code has already been provided for you, and you will need to implement additional functionality to successfully complete this project. You will not need to modify the included code beyond what is requested. Sections that begin with **'(IMPLEMENTATION)'** in the header indicate that the following block of code will require additional functionality which you must provide. Instructions will be provided for each section, and the specifics of the implementation are marked in the code block with a 'TODO' statement. Please be sure to read the instructions carefully!
#
# > **Note**: Once you have completed all of the code implementations, you need to finalize your work by exporting the Jupyter Notebook as an HTML document. Before exporting the notebook to html, all of the code cells need to have been run so that reviewers can see the final implementation and output. You can then export the notebook by using the menu above and navigating to **File -> Download as -> HTML (.html)**. Include the finished document along with this notebook as your submission.
#
# In addition to implementing code, there will be questions that you must answer which relate to the project and your implementation. Each section where you will answer a question is preceded by a **'Question X'** header. Carefully read each question and provide thorough answers in the following text boxes that begin with **'Answer:'**. Your project submission will be evaluated based on your answers to each of the questions and the implementation you provide.
#
# >**Note:** Code and Markdown cells can be executed using the **Shift + Enter** keyboard shortcut.  Markdown cells can be edited by double-clicking the cell to enter edit mode.
#
# The rubric contains _optional_ "Stand Out Suggestions" for enhancing the project beyond the minimum requirements. If you decide to pursue the "Stand Out Suggestions", you should include the code in this Jupyter notebook.
#
#
#
# ---
# ### Why We're Here
#
# In this notebook, you will make the first steps towards developing an algorithm that could be used as part of a mobile or web app.  At the end of this project, your code will accept any user-supplied image as input.  If a dog is detected in the image, it will provide an estimate of the dog's breed.  If a human is detected, it will provide an estimate of the dog breed that is most resembling.  The image below displays potential sample output of your finished project (... but we expect that each student's algorithm will behave differently!).
#
# ![Sample Dog Output](images/sample_dog_output.png)
#
# In this real-world setting, you will need to piece together a series of models to perform different tasks; for instance, the algorithm that detects humans in an image will be different from the CNN that infers dog breed.  There are many points of possible failure, and no perfect algorithm exists.  Your imperfect solution will nonetheless create a fun user experience!
#
# ### The Road Ahead
#
# We break the notebook into separate steps.  Feel free to use the links below to navigate the notebook.
#
# * [Step 0](#step0): Import Datasets
# * [Step 1](#step1): Detect Humans
# * [Step 2](#step2): Detect Dogs
# * [Step 3](#step3): Create a CNN to Classify Dog Breeds (from Scratch)
# * [Step 4](#step4): Create a CNN to Classify Dog Breeds (using Transfer Learning)
# * [Step 5](#step5): Write your Algorithm
# * [Step 6](#step6): Test Your Algorithm
#
# ---
# <a id='step0'></a>
# ## Step 0: Import Datasets
#
# Make sure that you've downloaded the required human and dog datasets:
#
# **Note: if you are using the Udacity workspace, you *DO NOT* need to re-download these - they can be found in the `/data` folder as noted in the cell below.**
#
# * Download the [dog dataset](https://s3-us-west-1.amazonaws.com/udacity-aind/dog-project/dogImages.zip).  Unzip the folder and place it in this project's home directory, at the location `/dog_images`.
#
# * Download the [human dataset](https://s3-us-west-1.amazonaws.com/udacity-aind/dog-project/lfw.zip).  Unzip the folder and place it in the home directory, at location `/lfw`.
#
# *Note: If you are using a Windows machine, you are encouraged to use [7zip](http://www.7-zip.org/) to extract the folder.*
#
# In the code cell below, we save the file paths for both the human (LFW) dataset and dog dataset in the numpy arrays `human_files` and `dog_files`.

# %%
import numpy as np
from glob import glob

# load filenames for human and dog images
human_files = np.array(glob("/data/lfw/*/*"))
dog_files = np.array(glob("/data/dog_images/*/*/*"))

# print number of images in each dataset
print('There are %d total human images.' % len(human_files))
print('There are %d total dog images.' % len(dog_files))
# Out:
# There are 13233 total human images.
# There are 8351 total dog images.

# %% [markdown]
# <a id='step1'></a>
# ## Step 1: Detect Humans
#
# In this section, we use OpenCV's implementation of [Haar feature-based cascade classifiers](http://docs.opencv.org/trunk/d7/d8b/tutorial_py_face_detection.html) to detect human faces in images.
#
# OpenCV provides many pre-trained face detectors, stored as XML files on [github](https://github.com/opencv/opencv/tree/master/data/haarcascades).  We have downloaded one of these detectors and stored it in the `haarcascades` directory.  In the next code cell, we demonstrate how to use this detector to find human faces in a sample image.

# %%
import cv2                
import matplotlib.pyplot as plt                        
# %matplotlib inline                               

# extract pre-trained face detector
face_cascade = cv2.CascadeClassifier('haarcascades/haarcascade_frontalface_alt.xml')

# load color (BGR) image
img = cv2.imread(human_files[0])
# convert BGR image to grayscale
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# find faces in image
faces = face_cascade.detectMultiScale(gray)

# print number of faces detected in the image
print('Number of faces detected:', len(faces))

# get bounding box for each detected face
for (x,y,w,h) in faces:
    # add bounding box to color image
    cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
    
# convert BGR image to RGB for plotting
cv_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# display the image, along with bounding box
plt.imshow(cv_rgb)
plt.show()
# Out:
# Number of faces detected: 1

# %% [markdown]
# Before using any of the face detectors, it is standard procedure to convert the images to grayscale.  The `detectMultiScale` function executes the classifier stored in `face_cascade` and takes the grayscale image as a parameter.
#
# In the above code, `faces` is a numpy array of detected faces, where each row corresponds to a detected face.  Each detected face is a 1D array with four entries that specifies the bounding box of the detected face.  The first two entries in the array (extracted in the above code as `x` and `y`) specify the horizontal and vertical positions of the top left corner of the bounding box.  The last two entries in the array (extracted here as `w` and `h`) specify the width and height of the box.
#
# ### Write a Human Face Detector
#
# We can use this procedure to write a function that returns `True` if a human face is detected in an image and `False` otherwise.  This function, aptly named `face_detector`, takes a string-valued file path to an image as input and appears in the code block below.

# %%
# returns "True" if face is detected in image stored at img_path
def face_detector(img_path):
    img = cv2.imread(img_path)
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    faces = face_cascade.detectMultiScale(gray)
    return len(faces) > 0

# %% [markdown]
# ### (IMPLEMENTATION) Assess the Human Face Detector
#
# __Question 1:__ Use the code cell below to test the performance of the `face_detector` function.
# - What percentage of the first 100 images in `human_files` have a detected human face?
# - What percentage of the first 100 images in `dog_files` have a detected human face?
#
# Ideally, we would like 100% of human images with a detected face and 0% of dog images with a detected face.  You will see that our algorithm falls short of this goal, but still gives acceptable performance.  We extract the file paths for the first 100 images from each of the datasets and store them in the numpy arrays `human_files_short` and `dog_files_short`.

# %% [markdown]
# __Answer:__
# (You can print out your results and/or write your percentages in this cell)

# %%
from tqdm import tqdm

human_files_short = human_files[:100]
dog_files_short = dog_files[:100]

#-#-# Do NOT modify the code above this line. #-#-#

## DONE: Test the performance of the face_detector algorithm 
## on the images in human_files_short and dog_files_short.

def asssess_detector(model, files, image_type_str):
    
    result = np.array([ 1 if model(image) else 0  for image in files ])
    percentage = result.sum()

    print(percentage,'% is the percentage of', image_type_str, 'images with a detected face')

asssess_detector(face_detector, human_files_short, 'human')
asssess_detector(face_detector, dog_files_short, 'dog')
# Out:
# 98 % is the percentage of human images with a detected face
# 17 % is the percentage of dog images with a detected face

# %% [markdown]
# We suggest the face detector from OpenCV as a potential way to detect human images in your algorithm, but you are free to explore other approaches, especially approaches that make use of deep learning :).  Please use the code cell below to design and test your own face detection algorithm.  If you decide to pursue this _optional_ task, report performance on `human_files_short` and `dog_files_short`.

# %%
### (Optional) 
### TODO: Test performance of anotherface detection algorithm.
### Feel free to use as many code cells as needed.

# %% [markdown]
# ---
# <a id='step2'></a>
# ## Step 2: Detect Dogs
#
# In this section, we use a [pre-trained model](http://pytorch.org/docs/master/torchvision/models.html) to detect dogs in images.
#
# ### Obtain Pre-trained VGG-16 Model
#
# The code cell below downloads the VGG-16 model, along with weights that have been trained on [ImageNet](http://www.image-net.org/), a very large, very popular dataset used for image classification and other vision tasks.  ImageNet contains over 10 million URLs, each linking to an image containing an object from one of [1000 categories](https://gist.github.com/yrevar/942d3a0ac09ec9e5eb3a).

# %%
import torch
import torchvision.models as models

# define VGG16 model
VGG16 = models.vgg16(pretrained=True)

# check if CUDA is available
use_cuda = torch.cuda.is_available()

# move model to GPU if CUDA is available
if use_cuda:
    VGG16 = VGG16.cuda()

# %% [markdown]
# Given an image, this pre-trained VGG-16 model returns a prediction (derived from the 1000 possible categories in ImageNet) for the object that is contained in the image.

# %% [markdown]
# ### (IMPLEMENTATION) Making Predictions with a Pre-trained Model
#
# In the next code cell, you will write a function that accepts a path to an image (such as `'dogImages/train/001.Affenpinscher/Affenpinscher_00001.jpg'`) as input and returns the index corresponding to the ImageNet class that is predicted by the pre-trained VGG-16 model.  The output should always be an integer between 0 and 999, inclusive.
#
# Before writing the function, make sure that you take the time to learn  how to appropriately pre-process tensors for pre-trained models in the [PyTorch documentation](http://pytorch.org/docs/stable/torchvision/models.html).

# %%
from torchvision import datasets, models, transforms
from PIL import Image

def load_image(img_path):
    data_transforms = transforms.Compose([transforms.Resize(256),
                                           transforms.RandomResizedCrop(224),
                                           transforms.ToTensor(),
                                           transforms.Normalize([0.485, 0.456, 0.406],
                                                                [0.229, 0.224, 0.225])])

    
    image = Image.open(img_path)
    tensor = data_transforms(image)

    
    return tensor

# %%
import torchvision.transforms as transforms

def VGG16_predict(img_path):
    '''
    Use pre-trained VGG-16 model to obtain index corresponding to 
    predicted ImageNet class for image at specified path
    
    Args:
        img_path: path to an image
        
    Returns:
        Index corresponding to VGG-16 model's prediction
    '''
    
    ## DONE: Complete the function.
    ## Load and pre-process an image from the given img_path
    ## Return the *index* of the predicted class for that image
    image_tensor = load_image(img_path)
    if use_cuda:
        image_tensor = image_tensor.cuda()
    logps = VGG16.forward(image_tensor.unsqueeze_(0))
    ps = torch.exp(logps)
    top_p, top_class = ps.topk(1, dim=1)
    return top_class[0].cpu().numpy() # predicted class index

# %% [markdown]
# ### (IMPLEMENTATION) Write a Dog Detector
#
# While looking at the [dictionary](https://gist.github.com/yrevar/942d3a0ac09ec9e5eb3a), you will notice that the categories corresponding to dogs appear in an uninterrupted sequence and correspond to dictionary keys 151-268, inclusive, to include all categories from `'Chihuahua'` to `'Mexican hairless'`.  Thus, in order to check to see if an image is predicted to contain a dog by the pre-trained VGG-16 model, we need only check if the pre-trained model predicts an index between 151 and 268 (inclusive).
#
# Use these ideas to complete the `dog_detector` function below, which returns `True` if a dog is detected in an image (and `False` if not).

# %%
### returns "True" if a dog is detected in the image stored at img_path
def dog_detector(img_path):
    ## DONE: Complete the function.
    predicted_class_index = VGG16_predict(img_path)
    
    if predicted_class_index > 150 and predicted_class_index < 269 :
        return True 
    return False
# true/false

# %% [markdown]
# ### (IMPLEMENTATION) Assess the Dog Detector
#
# __Question 2:__ Use the code cell below to test the performance of your `dog_detector` function.
# - What percentage of the images in `human_files_short` have a detected dog?
# - What percentage of the images in `dog_files_short` have a detected dog?

# %% [markdown]
# __Answer:__

# %%
### DONE: Test the performance of the dog_detector function
### on the images in human_files_short and dog_files_short.
asssess_detector(dog_detector, human_files_short, 'human')
asssess_detector(dog_detector, dog_files_short, 'dog')
# Out:
# 1 % is the percentage of human images with a detected face
# 99 % is the percentage of dog images with a detected face

# %% [markdown]
# We suggest VGG-16 as a potential network to detect dog images in your algorithm, but you are free to explore other pre-trained networks (such as [Inception-v3](http://pytorch.org/docs/master/torchvision/models.html#inception-v3), [ResNet-50](http://pytorch.org/docs/master/torchvision/models.html#id3), etc).  Please use the code cell below to test other pre-trained PyTorch models.  If you decide to pursue this _optional_ task, report performance on `human_files_short` and `dog_files_short`.

# %%
### (Optional) 
### TODO: Report the performance of another pre-trained network.
### Feel free to use as many code cells as needed.

# %% [markdown]
# ---
# <a id='step3'></a>
# ## Step 3: Create a CNN to Classify Dog Breeds (from Scratch)
#
# Now that we have functions for detecting humans and dogs in images, we need a way to predict breed from images.  In this step, you will create a CNN that classifies dog breeds.  You must create your CNN _from scratch_ (so, you can't use transfer learning _yet_!), and you must attain a test accuracy of at least 10%.  In Step 4 of this notebook, you will have the opportunity to use transfer learning to create a CNN that attains greatly improved accuracy.
#
# We mention that the task of assigning breed to dogs from images is considered exceptionally challenging.  To see why, consider that *even a human* would have trouble distinguishing between a Brittany and a Welsh Springer Spaniel.
#
# Brittany | Welsh Springer Spaniel
# - | -
# <img src="images/Brittany_02625.jpg" width="100"> | <img src="images/Welsh_springer_spaniel_08203.jpg" width="200">
#
# It is not difficult to find other dog breed pairs with minimal inter-class variation (for instance, Curly-Coated Retrievers and American Water Spaniels).
#
# Curly-Coated Retriever | American Water Spaniel
# - | -
# <img src="images/Curly-coated_retriever_03896.jpg" width="200"> | <img src="images/American_water_spaniel_00648.jpg" width="200">
#
#
# Likewise, recall that labradors come in yellow, chocolate, and black.  Your vision-based algorithm will have to conquer this high intra-class variation to determine how to classify all of these different shades as the same breed.
#
# Yellow Labrador | Chocolate Labrador | Black Labrador
# - | -
# <img src="images/Labrador_retriever_06457.jpg" width="150"> | <img src="images/Labrador_retriever_06455.jpg" width="240"> | <img src="images/Labrador_retriever_06449.jpg" width="220">
#
# We also mention that random chance presents an exceptionally low bar: setting aside the fact that the classes are slightly imabalanced, a random guess will provide a correct answer roughly 1 in 133 times, which corresponds to an accuracy of less than 1%.
#
# Remember that the practice is far ahead of the theory in deep learning.  Experiment with many different architectures, and trust your intuition.  And, of course, have fun!
#
# ### (IMPLEMENTATION) Specify Data Loaders for the Dog Dataset
#
# Use the code cell below to write three separate [data loaders](http://pytorch.org/docs/stable/data.html#torch.utils.data.DataLoader) for the training, validation, and test datasets of dog images (located at `dog_images/train`, `dog_images/valid`, and `dog_images/test`, respectively).  You may find [this documentation on custom datasets](http://pytorch.org/docs/stable/torchvision/datasets.html) to be a useful resource.  If you are interested in augmenting your training and/or validation data, check out the wide variety of [transforms](http://pytorch.org/docs/stable/torchvision/transforms.html?highlight=transform)!

# %%
import torchvision
import torch
from torchvision import datasets
import torchvision.transforms as transforms


### DONE: Write data loaders for training, validation, and test sets
## Specify appropriate transforms, and batch_sizes

batch_size = 20
root_dir = '/data/dog_images/'

data_transforms = transforms.Compose([transforms.Resize(256),
                                      transforms.RandomResizedCrop(224),
                                      transforms.ToTensor(),
                                      transforms.Normalize([0.485, 0.456, 0.406],
                                                           [0.229, 0.224, 0.225]),
                                     ])



# Reading Dataset
image_datasets = {
    'train' : torchvision.datasets.ImageFolder(root = root_dir+'train',transform = data_transforms),
    'valid' : torchvision.datasets.ImageFolder(root = root_dir+'valid',transform = data_transforms),
    'test' : torchvision.datasets.ImageFolder(root = root_dir+'test',transform = data_transforms)
}

loaders_scratch = {
    'train' : torch.utils.data.DataLoader(image_datasets['train'],batch_size = batch_size,shuffle=True),
    'valid' : torch.utils.data.DataLoader(image_datasets['valid'],batch_size = batch_size),
    'test' : torch.utils.data.DataLoader(image_datasets['test'],batch_size = batch_size)    
}

# %% [markdown]
# **Question 3:** Describe your chosen procedure for preprocessing the data.
# - How does your code resize the images (by cropping, stretching, etc)?  What size did you pick for the input tensor, and why?
# - Did you decide to augment the dataset?  If so, how (through translations, flips, rotations, etc)?  If not, why not?

# %% [markdown]
# **Answer**:

# %% [markdown]
#  - I preprocessed the image be first resized them to 256 then cropping them with 224 and also, normalized them, I took these steps from preprocessing images for pretrained model.
#
#  - I didn't do any augmentation  becuse that may incease the complexity and increase the time of training.

# %%
len(image_datasets['train'])
# Out:
# 6680

# %%
print("image shape are: "+str(image_datasets['train'][0][0].shape))
# Out:
# image shape are: torch.Size([3, 224, 224])

# %%
print("Number of classes are: "+str(len(image_datasets['train'].classes)))
# Out:
# Number of classes are: 133

# %% [markdown]
# ### (IMPLEMENTATION) Model Architecture
#
# Create a CNN to classify dog breed.  Use the template in the code cell below.

# %%
import torch.nn as nn
import torch.nn.functional as F

# define the CNN architecture
class Net(nn.Module):
    ### TODO: choose an architecture, and complete the class
    def __init__(self):
        super(Net, self).__init__()

        self.n_output = 133
        self.n_input = 256 * 7 * 7
        
        ## Define layers of a CNN
        self.conv1 = nn.Conv2d(3, 16, 3, padding=1)
        self.conv2 = nn.Conv2d(16, 32, 3, padding=1)
        self.conv3 = nn.Conv2d(32, 64, 3, padding=1)
        self.conv4 = nn.Conv2d(64, 128, 3, padding=1)
        self.conv5 = nn.Conv2d(128, 256, 3, padding=1)

        self.max_pool = nn.MaxPool2d(2, 2)

        self.fc1 = nn.Linear(self.n_input, 6272)
        self.fc2 = nn.Linear(6272, 3136)
        self.fc3 = nn.Linear(3136, 1568)
        self.fc4 = nn.Linear(1568, 784)
        self.fc5 = nn.Linear(784, self.n_output)
        self.dropout = nn.Dropout(0.4)
    
    def forward(self, x):
        ## Define forward behavior
        x = self.max_pool(F.relu(self.conv1(x)))
        x = self.max_pool(F.relu(self.conv2(x)))
        x = self.max_pool(F.relu(self.conv3(x)))
        x = self.max_pool(F.relu(self.conv4(x)))
        x = self.max_pool(F.relu(self.conv5(x)))

        # flatten image input
        x = x.view(-1, self.n_input)
        
        x = self.dropout(F.relu(self.fc1(x)))
        x = self.dropout(F.relu(self.fc2(x)))
        x = self.dropout(F.relu(self.fc3(x)))
        x = self.dropout(F.relu(self.fc4(x)))
        x = F.log_softmax(self.fc5(x), dim=1)

        return x
    
    

#-#-# You so NOT have to modify the code below this line. #-#-#

# instantiate the CNN
model_scratch = Net()

use_cuda = torch.cuda.is_available()

# move tensors to GPU if CUDA is available
if use_cuda:
    model_scratch.cuda()

# %% [markdown]
# __Question 4:__ Outline the steps you took to get to your final CNN architecture and your reasoning at each step.

# %% [markdown]
# __Answer:__

# %% [markdown]
# - The first version was 3 convolutional layers and 2  Linear layers
# - The second version was 5 convolutional layers and 2  Linear layers
#
# at the first and second versions, the loss was converging very slowly so, I had to improve the structure
#
# - The third and last version was 5 convolutional layers and 5  Linear layers
#
# finally, the model shows acceptable performance
#  two hours to get 10%
#
# - Also, I change the activation function fot the output from sgmoid to log_softmax

# %% [markdown]
# ### (IMPLEMENTATION) Specify Loss Function and Optimizer
#
# Use the next code cell to specify a [loss function](http://pytorch.org/docs/stable/nn.html#loss-functions) and [optimizer](http://pytorch.org/docs/stable/optim.html).  Save the chosen loss function as `criterion_scratch`, and the optimizer as `optimizer_scratch` below.

# %%
import torch.optim as optim

### DONE: select loss function
criterion_scratch = nn.NLLLoss()



### DONE: select optimizer
optimizer_scratch = optim.Adam(model_scratch.parameters(), lr=0.00001)

# %% [markdown]
# ### (IMPLEMENTATION) Train and Validate the Model
#
# Train and validate your model in the code cell below.  [Save the final model parameters](http://pytorch.org/docs/master/notes/serialization.html) at filepath `'model_scratch.pt'`.

# %%
import numpy as np

# the following import is required for training to be robust to truncated images
from PIL import ImageFile
ImageFile.LOAD_TRUNCATED_IMAGES = True

def train(n_epochs, loaders, model, optimizer, criterion, use_cuda, save_path):

    """returns trained model"""
    # initialize tracker for minimum validation loss
    valid_loss_min = np.Inf 

    
    for epoch in range(1, n_epochs+1):
        # initialize variables to monitor training and validation loss
        train_loss = 0.0
        valid_loss = 0.0
        
        correct = 0.
        total = 0.
        
        ###################
        # train the model #
        ###################
        model.train()
        for batch_idx, (data, target) in enumerate(loaders['train']):
            
            # move to GPU
            if use_cuda:
                data, target = data.cuda(), target.cuda()
            ## find the loss and update the model parameters accordingly
            ## record the average training loss, using something like
            ## train_loss = train_loss + ((1 / (batch_idx + 1)) * (loss.data - train_loss))

            optimizer.zero_grad()           
            output = model(data)
            loss = criterion(output, target)
            loss.backward()
            optimizer.step() 
            train_loss = train_loss + ((1 / (batch_idx + 1)) * (loss.data - train_loss))


            
        ######################    
        # validate the model #
        ######################
        model.eval()
        
        for batch_idx, (data, target) in enumerate(loaders['valid']):    
            # move to GPU
            if use_cuda:
                data, target = data.cuda(), target.cuda()
                
            ## update the average validation loss
            output = model.forward(data)
            loss = criterion(output, target)
            valid_loss = valid_loss + ((1 / (batch_idx + 1)) * (loss.data - valid_loss))

            pred = output.data.max(1, keepdim=True)[1]
            # compare predictions to true label
            correct += np.sum(np.squeeze(pred.eq(target.data.view_as(pred))).cpu().numpy())
            total += data.size(0)

        # print training/validation statistics 
        print('Epoch: {} \tTraining Loss: {:.6f} \tValidation Loss: {:.6f}'.format(
            epoch, 
            train_loss,
            valid_loss
            ))
        
        ## DONE: save the model if validation loss has decreased
        if valid_loss <= valid_loss_min :
            print('Validation loss decreased ({:.6f} --> {:.6f}).  Saving model ...'.format(
            valid_loss_min,
            valid_loss))
            torch.save(model.state_dict(), save_path)
            
            valid_loss_min = valid_loss
            
        print('\nTest Accuracy: %2d%% (%2d/%2d)' % (
        100. * correct / total, correct, total))
    # return trained model
    return model

# %%
# train the model
model_scratch = train(150, loaders_scratch, model_scratch, optimizer_scratch, 
                      criterion_scratch, use_cuda, 'model_scratch.pt')
# Out:
# Epoch: 1 	Training Loss: 4.890055 	Validation Loss: 4.888060
# Validation loss decreased (inf --> 4.888060).  Saving model ...
#
# Test Accuracy:  1% (12/835)
# Epoch: 2 	Training Loss: 4.879991 	Validation Loss: 4.866670
# Validation loss decreased (4.888060 --> 4.866670).  Saving model ...
#
# Test Accuracy:  1% ( 9/835)
# Epoch: 3 	Training Loss: 4.868236 	Validation Loss: 4.862216
# Validation loss decreased (4.866670 --> 4.862216).  Saving model ...
#
# Test Accuracy:  1% ( 9/835)
# Epoch: 4 	Training Loss: 4.859864 	Validation Loss: 4.853383
# Validation loss decreased (4.862216 --> 4.853383).  Saving model ...
#
# Test Accuracy:  0% ( 8/835)
# Epoch: 5 	Training Loss: 4.848715 	Validation Loss: 4.837976
# Validation loss decreased (4.853383 --> 4.837976).  Saving model ...
#
# Test Accuracy:  1% (11/835)
# Epoch: 6 	Training Loss: 4.831828 	Validation Loss: 4.816518
# Validation loss decreased (4.837976 --> 4.816518).  Saving model ...
#
# Test Accuracy:  1% (10/835)
# Epoch: 7 	Training Loss: 4.799984 	Validation Loss: 4.781791
# Validation loss decreased (4.816518 --> 4.781791).  Saving model ...
#
# Test Accuracy:  1% (15/835)
# Epoch: 8 	Training Loss: 4.767400 	Validation Loss: 4.764602
# Validation loss decreased (4.781791 --> 4.764602).  Saving model ...
#
# Test Accuracy:  1% (16/835)
# Epoch: 9 	Training Loss: 4.755314 	Validation Loss: 4.742674
# Validation loss decreased (4.764602 --> 4.742674).  Saving model ...
#
# Test Accuracy:  2% (17/835)
# Epoch: 10 	Training Loss: 4.736632 	Validation Loss: 4.733507
# Validation loss decreased (4.742674 --> 4.733507).  Saving model ...
#
# Test Accuracy:  2% (20/835)
# Epoch: 11 	Training Loss: 4.724902 	Validation Loss: 4.724057
# Validation loss decreased (4.733507 --> 4.724057).  Saving model ...
#
# Test Accuracy:  1% (16/835)
# Epoch: 12 	Training Loss: 4.716615 	Validation Loss: 4.698877
# Validation loss decreased (4.724057 --> 4.698877).  Saving model ...
#
# Test Accuracy:  2% (19/835)
# Epoch: 13 	Training Loss: 4.703347 	Validation Loss: 4.702878
#
# Test Accuracy:  2% (20/835)
# Epoch: 14 	Training Loss: 4.703913 	Validation Loss: 4.711318
#
# Test Accuracy:  2% (22/835)
# Epoch: 15 	Training Loss: 4.684204 	Validation Loss: 4.701984
#
# Test Accuracy:  2% (21/835)
# Epoch: 16 	Training Loss: 4.665397 	Validation Loss: 4.671300
# Validation loss decreased (4.698877 --> 4.671300).  Saving model ...
#
# Test Accuracy:  2% (21/835)
# Epoch: 17 	Training Loss: 4.664630 	Validation Loss: 4.666685
# Validation loss decreased (4.671300 --> 4.666685).  Saving model ...
#
# Test Accuracy:  2% (23/835)
# Epoch: 18 	Training Loss: 4.660369 	Validation Loss: 4.673120
#
# Test Accuracy:  2% (22/835)
# Epoch: 19 	Training Loss: 4.641649 	Validation Loss: 4.668383
#
# Test Accuracy:  3% (26/835)
# Epoch: 20 	Training Loss: 4.644101 	Validation Loss: 4.655838
# Validation loss decreased (4.666685 --> 4.655838).  Saving model ...
#
# Test Accuracy:  2% (19/835)
# Epoch: 21 	Training Loss: 4.626738 	Validation Loss: 4.663415
#
# Test Accuracy:  2% (25/835)
# Epoch: 22 	Training Loss: 4.625409 	Validation Loss: 4.615122
# Validation loss decreased (4.655838 --> 4.615122).  Saving model ...
#
# Test Accuracy:  3% (27/835)
# Epoch: 23 	Training Loss: 4.613013 	Validation Loss: 4.635163
#
# Test Accuracy:  2% (23/835)
# Epoch: 24 	Training Loss: 4.612669 	Validation Loss: 4.635980
#
# Test Accuracy:  2% (20/835)
# Epoch: 25 	Training Loss: 4.597420 	Validation Loss: 4.617500
#
# Test Accuracy:  3% (28/835)
# Epoch: 26 	Training Loss: 4.580140 	Validation Loss: 4.615942
#
# Test Accuracy:  2% (19/835)
# Epoch: 27 	Training Loss: 4.588965 	Validation Loss: 4.587304
# Validation loss decreased (4.615122 --> 4.587304).  Saving model ...
#
# Test Accuracy:  3% (26/835)
# Epoch: 28 	Training Loss: 4.566807 	Validation Loss: 4.573053
# Validation loss decreased (4.587304 --> 4.573053).  Saving model ...
#
# Test Accuracy:  3% (31/835)
# Epoch: 29 	Training Loss: 4.562755 	Validation Loss: 4.593486
#
# Test Accuracy:  3% (29/835)
# Epoch: 30 	Training Loss: 4.555927 	Validation Loss: 4.544734
# Validation loss decreased (4.573053 --> 4.544734).  Saving model ...
#
# Test Accuracy:  3% (31/835)
# Epoch: 31 	Training Loss: 4.550442 	Validation Loss: 4.597880
#
# Test Accuracy:  2% (21/835)
# Epoch: 32 	Training Loss: 4.548166 	Validation Loss: 4.566374
#
# Test Accuracy:  3% (27/835)
# Epoch: 33 	Training Loss: 4.535911 	Validation Loss: 4.564486
#
# Test Accuracy:  3% (27/835)
# Epoch: 34 	Training Loss: 4.531334 	Validation Loss: 4.542856
# Validation loss decreased (4.544734 --> 4.542856).  Saving model ...
#
# Test Accuracy:  3% (31/835)
# Epoch: 35 	Training Loss: 4.509113 	Validation Loss: 4.519034
# Validation loss decreased (4.542856 --> 4.519034).  Saving model ...
#
# Test Accuracy:  2% (25/835)
# Epoch: 36 	Training Loss: 4.506699 	Validation Loss: 4.525002
#
# Test Accuracy:  4% (37/835)
# Epoch: 37 	Training Loss: 4.488470 	Validation Loss: 4.501162
# Validation loss decreased (4.519034 --> 4.501162).  Saving model ...
#
# Test Accuracy:  3% (33/835)
# Epoch: 38 	Training Loss: 4.488942 	Validation Loss: 4.489495
# Validation loss decreased (4.501162 --> 4.489495).  Saving model ...
#
# Test Accuracy:  4% (41/835)
# Epoch: 39 	Training Loss: 4.473187 	Validation Loss: 4.487672
# Validation loss decreased (4.489495 --> 4.487672).  Saving model ...
#
# Test Accuracy:  4% (35/835)
# Epoch: 40 	Training Loss: 4.467632 	Validation Loss: 4.503127
#
# Test Accuracy:  3% (33/835)
# Epoch: 41 	Training Loss: 4.455900 	Validation Loss: 4.487619
# Validation loss decreased (4.487672 --> 4.487619).  Saving model ...
#
# Test Accuracy:  3% (33/835)
# Epoch: 42 	Training Loss: 4.449070 	Validation Loss: 4.451892
# Validation loss decreased (4.487619 --> 4.451892).  Saving model ...
#
# Test Accuracy:  4% (41/835)
# Epoch: 43 	Training Loss: 4.434837 	Validation Loss: 4.467720
#
# Test Accuracy:  4% (37/835)
# Epoch: 44 	Training Loss: 4.410221 	Validation Loss: 4.462080
#
# Test Accuracy:  3% (29/835)
# Epoch: 45 	Training Loss: 4.396996 	Validation Loss: 4.434475
# Validation loss decreased (4.451892 --> 4.434475).  Saving model ...
#
# Test Accuracy:  3% (33/835)
# Epoch: 46 	Training Loss: 4.397907 	Validation Loss: 4.420757
# Validation loss decreased (4.434475 --> 4.420757).  Saving model ...
#
# Test Accuracy:  2% (23/835)
# Epoch: 47 	Training Loss: 4.389251 	Validation Loss: 4.387918
# Validation loss decreased (4.420757 --> 4.387918).  Saving model ...
#
# Test Accuracy:  4% (35/835)
# Epoch: 48 	Training Loss: 4.364032 	Validation Loss: 4.407162
#
# Test Accuracy:  4% (35/835)
# Epoch: 49 	Training Loss: 4.353769 	Validation Loss: 4.404028
#
# Test Accuracy:  4% (41/835)
# Epoch: 50 	Training Loss: 4.328628 	Validation Loss: 4.390031
#
# Test Accuracy:  5% (43/835)
# Epoch: 51 	Training Loss: 4.339590 	Validation Loss: 4.355641
# Validation loss decreased (4.387918 --> 4.355641).  Saving model ...
#
# Test Accuracy:  5% (43/835)
# Epoch: 52 	Training Loss: 4.322028 	Validation Loss: 4.377779
#
# Test Accuracy:  4% (39/835)
# Epoch: 53 	Training Loss: 4.293815 	Validation Loss: 4.342540
# Validation loss decreased (4.355641 --> 4.342540).  Saving model ...
#
# Test Accuracy:  5% (42/835)
# Epoch: 54 	Training Loss: 4.298550 	Validation Loss: 4.320682
# Validation loss decreased (4.342540 --> 4.320682).  Saving model ...
#
# Test Accuracy:  5% (44/835)
# Epoch: 55 	Training Loss: 4.275403 	Validation Loss: 4.325465
#
# Test Accuracy:  5% (44/835)
# Epoch: 56 	Training Loss: 4.265435 	Validation Loss: 4.306272
# Validation loss decreased (4.320682 --> 4.306272).  Saving model ...
#
# Test Accuracy:  5% (47/835)
# Epoch: 57 	Training Loss: 4.252872 	Validation Loss: 4.386326
#
# Test Accuracy:  4% (38/835)
# Epoch: 58 	Training Loss: 4.236983 	Validation Loss: 4.270345
# Validation loss decreased (4.306272 --> 4.270345).  Saving model ...
#
# Test Accuracy:  6% (58/835)
# Epoch: 59 	Training Loss: 4.236932 	Validation Loss: 4.278505
#
# Test Accuracy:  5% (47/835)
# Epoch: 60 	Training Loss: 4.221376 	Validation Loss: 4.250640
# Validation loss decreased (4.270345 --> 4.250640).  Saving model ...
#
# Test Accuracy:  6% (54/835)
# Epoch: 61 	Training Loss: 4.201458 	Validation Loss: 4.259751
#
# Test Accuracy:  6% (51/835)
# Epoch: 62 	Training Loss: 4.207057 	Validation Loss: 4.241441
# Validation loss decreased (4.250640 --> 4.241441).  Saving model ...
#
# Test Accuracy:  5% (46/835)
# Epoch: 63 	Training Loss: 4.207160 	Validation Loss: 4.244043
#
# Test Accuracy:  6% (51/835)
# Epoch: 64 	Training Loss: 4.202710 	Validation Loss: 4.260929
#
# Test Accuracy:  6% (56/835)
# Epoch: 65 	Training Loss: 4.180485 	Validation Loss: 4.239065
# Validation loss decreased (4.241441 --> 4.239065).  Saving model ...
#
# Test Accuracy:  5% (42/835)
# Epoch: 66 	Training Loss: 4.181925 	Validation Loss: 4.195354
# Validation loss decreased (4.239065 --> 4.195354).  Saving model ...
#
# Test Accuracy:  6% (54/835)
# Epoch: 67 	Training Loss: 4.158436 	Validation Loss: 4.222665
#
# Test Accuracy:  5% (48/835)
# Epoch: 68 	Training Loss: 4.165575 	Validation Loss: 4.201747
#
# Test Accuracy:  6% (55/835)
# Epoch: 69 	Training Loss: 4.160947 	Validation Loss: 4.183897
# Validation loss decreased (4.195354 --> 4.183897).  Saving model ...
#
# Test Accuracy:  7% (59/835)
# Epoch: 70 	Training Loss: 4.145112 	Validation Loss: 4.239404
#
# Test Accuracy:  5% (46/835)
# Epoch: 71 	Training Loss: 4.134483 	Validation Loss: 4.164296
# Validation loss decreased (4.183897 --> 4.164296).  Saving model ...
#
# Test Accuracy:  6% (57/835)
# Epoch: 72 	Training Loss: 4.127999 	Validation Loss: 4.177323
#
# Test Accuracy:  5% (49/835)
# Epoch: 73 	Training Loss: 4.120465 	Validation Loss: 4.153595
# Validation loss decreased (4.164296 --> 4.153595).  Saving model ...
#
# Test Accuracy:  7% (59/835)
# Epoch: 74 	Training Loss: 4.108308 	Validation Loss: 4.163565
#
# Test Accuracy:  6% (54/835)
# Epoch: 75 	Training Loss: 4.115827 	Validation Loss: 4.164151
#
# Test Accuracy:  6% (58/835)
# Epoch: 76 	Training Loss: 4.092188 	Validation Loss: 4.179543
#
# Test Accuracy:  6% (54/835)
# Epoch: 77 	Training Loss: 4.101863 	Validation Loss: 4.165782
#
# Test Accuracy:  6% (55/835)
# Epoch: 78 	Training Loss: 4.094762 	Validation Loss: 4.141527
# Validation loss decreased (4.153595 --> 4.141527).  Saving model ...
#
# Test Accuracy:  6% (51/835)
# Epoch: 79 	Training Loss: 4.079780 	Validation Loss: 4.134459
# Validation loss decreased (4.141527 --> 4.134459).  Saving model ...
#
# Test Accuracy:  5% (50/835)
# Epoch: 80 	Training Loss: 4.076198 	Validation Loss: 4.188647
#
# Test Accuracy:  6% (55/835)
# Epoch: 81 	Training Loss: 4.076555 	Validation Loss: 4.173553
#
# Test Accuracy:  6% (51/835)
# Epoch: 82 	Training Loss: 4.076261 	Validation Loss: 4.166591
#
# Test Accuracy:  5% (49/835)
# Epoch: 83 	Training Loss: 4.056919 	Validation Loss: 4.102951
# Validation loss decreased (4.134459 --> 4.102951).  Saving model ...
#
# Test Accuracy:  7% (62/835)
# Epoch: 84 	Training Loss: 4.047802 	Validation Loss: 4.128863
#
# Test Accuracy:  7% (62/835)
# Epoch: 85 	Training Loss: 4.040240 	Validation Loss: 4.154793
#
# Test Accuracy:  6% (55/835)
# Epoch: 86 	Training Loss: 4.037200 	Validation Loss: 4.092934
# Validation loss decreased (4.102951 --> 4.092934).  Saving model ...
#
# Test Accuracy:  7% (61/835)
# Epoch: 87 	Training Loss: 4.026175 	Validation Loss: 4.106194
#
# Test Accuracy:  5% (47/835)
# Epoch: 88 	Training Loss: 4.041531 	Validation Loss: 4.077692
# Validation loss decreased (4.092934 --> 4.077692).  Saving model ...
#
# Test Accuracy:  7% (66/835)
# Epoch: 89 	Training Loss: 4.046987 	Validation Loss: 4.136080
#
# Test Accuracy:  6% (51/835)
# Epoch: 90 	Training Loss: 4.034655 	Validation Loss: 4.127269
#
# Test Accuracy:  7% (60/835)
# Epoch: 91 	Training Loss: 4.008300 	Validation Loss: 4.139060
#
# Test Accuracy:  7% (60/835)
# Epoch: 92 	Training Loss: 3.996837 	Validation Loss: 4.101007
#
# Test Accuracy:  6% (55/835)
# Epoch: 93 	Training Loss: 4.011598 	Validation Loss: 4.111523
#
# Test Accuracy:  6% (52/835)
# Epoch: 94 	Training Loss: 4.002306 	Validation Loss: 4.109166
#
# Test Accuracy:  7% (64/835)
# Epoch: 95 	Training Loss: 3.993441 	Validation Loss: 4.089817
#
# Test Accuracy:  6% (57/835)
# Epoch: 96 	Training Loss: 3.983376 	Validation Loss: 4.063574
# Validation loss decreased (4.077692 --> 4.063574).  Saving model ...
#
# Test Accuracy:  7% (59/835)
# Epoch: 97 	Training Loss: 3.975114 	Validation Loss: 4.073357
#
# Test Accuracy:  6% (51/835)
# Epoch: 98 	Training Loss: 3.966027 	Validation Loss: 4.085010
#
# Test Accuracy:  6% (58/835)
# Epoch: 99 	Training Loss: 3.975706 	Validation Loss: 4.117319
#
# Test Accuracy:  6% (51/835)
# Epoch: 100 	Training Loss: 3.978482 	Validation Loss: 4.068274
#
# Test Accuracy:  6% (52/835)
# Epoch: 101 	Training Loss: 3.952646 	Validation Loss: 4.064200
#
# Test Accuracy:  7% (59/835)
# Epoch: 102 	Training Loss: 3.932093 	Validation Loss: 4.079268
#
# Test Accuracy:  7% (66/835)
# Epoch: 103 	Training Loss: 3.939256 	Validation Loss: 4.040763
# Validation loss decreased (4.063574 --> 4.040763).  Saving model ...
#
# Test Accuracy:  7% (62/835)
# Epoch: 104 	Training Loss: 3.926838 	Validation Loss: 4.047973
#
# Test Accuracy:  6% (58/835)
# Epoch: 105 	Training Loss: 3.949316 	Validation Loss: 4.070477
#
# Test Accuracy:  7% (61/835)
# Epoch: 106 	Training Loss: 3.934706 	Validation Loss: 4.066117
#
# Test Accuracy:  7% (64/835)
# Epoch: 107 	Training Loss: 3.912694 	Validation Loss: 3.977567
# Validation loss decreased (4.040763 --> 3.977567).  Saving model ...
#
# Test Accuracy:  7% (60/835)
# Epoch: 108 	Training Loss: 3.921393 	Validation Loss: 4.044137
#
# Test Accuracy:  7% (64/835)
# Epoch: 109 	Training Loss: 3.903143 	Validation Loss: 4.021142
#
# Test Accuracy:  7% (61/835)
# Epoch: 110 	Training Loss: 3.901927 	Validation Loss: 4.006798
#
# Test Accuracy:  9% (80/835)
# Epoch: 111 	Training Loss: 3.902559 	Validation Loss: 3.996579
#
# Test Accuracy:  8% (68/835)
# Epoch: 112 	Training Loss: 3.922142 	Validation Loss: 4.063766
#
# Test Accuracy:  8% (67/835)
# Epoch: 113 	Training Loss: 3.874640 	Validation Loss: 4.096199
#
# Test Accuracy:  8% (68/835)
# Epoch: 114 	Training Loss: 3.891274 	Validation Loss: 4.043580
#
# Test Accuracy:  6% (55/835)
# Epoch: 115 	Training Loss: 3.879920 	Validation Loss: 4.010872
#
# Test Accuracy:  8% (73/835)
# Epoch: 116 	Training Loss: 3.858003 	Validation Loss: 3.982571
#
# Test Accuracy:  9% (79/835)
# Epoch: 117 	Training Loss: 3.874505 	Validation Loss: 4.034498
#
# Test Accuracy:  8% (70/835)
# Epoch: 118 	Training Loss: 3.867294 	Validation Loss: 4.000960
#
# Test Accuracy:  8% (69/835)
# Epoch: 119 	Training Loss: 3.877986 	Validation Loss: 4.018054
#
# Test Accuracy:  8% (68/835)
# Epoch: 120 	Training Loss: 3.862009 	Validation Loss: 4.007950
#
# Test Accuracy:  8% (68/835)
# Epoch: 121 	Training Loss: 3.859413 	Validation Loss: 3.997082
#
# Test Accuracy:  8% (67/835)
# Epoch: 122 	Training Loss: 3.851117 	Validation Loss: 3.968112
# Validation loss decreased (3.977567 --> 3.968112).  Saving model ...
#
# Test Accuracy:  9% (83/835)
# Epoch: 123 	Training Loss: 3.853662 	Validation Loss: 3.973140
#
# Test Accuracy:  7% (62/835)
# Epoch: 124 	Training Loss: 3.871344 	Validation Loss: 3.970133
#
# Test Accuracy:  7% (66/835)
# Epoch: 125 	Training Loss: 3.839742 	Validation Loss: 3.988099
#
# Test Accuracy:  8% (74/835)
# Epoch: 126 	Training Loss: 3.838560 	Validation Loss: 3.944823
# Validation loss decreased (3.968112 --> 3.944823).  Saving model ...
#
# Test Accuracy:  9% (81/835)
# Epoch: 127 	Training Loss: 3.831512 	Validation Loss: 3.926481
# Validation loss decreased (3.944823 --> 3.926481).  Saving model ...
#
# Test Accuracy:  8% (69/835)
# Epoch: 128 	Training Loss: 3.820966 	Validation Loss: 3.970993
#
# Test Accuracy:  9% (79/835)
# Epoch: 129 	Training Loss: 3.807256 	Validation Loss: 3.924828
# Validation loss decreased (3.926481 --> 3.924828).  Saving model ...
#
# Test Accuracy: 10% (87/835)
# Epoch: 130 	Training Loss: 3.809426 	Validation Loss: 3.977038
#
# Test Accuracy:  9% (80/835)
# Epoch: 131 	Training Loss: 3.801425 	Validation Loss: 3.949830
#
# Test Accuracy:  9% (79/835)
# Epoch: 132 	Training Loss: 3.812582 	Validation Loss: 3.988019
#
# Test Accuracy:  8% (75/835)
# Epoch: 133 	Training Loss: 3.791151 	Validation Loss: 3.957049
#
# Test Accuracy:  9% (80/835)
# Epoch: 134 	Training Loss: 3.784534 	Validation Loss: 3.956804
#
# Test Accuracy:  9% (83/835)
# Epoch: 135 	Training Loss: 3.797194 	Validation Loss: 3.971221
#
# Test Accuracy:  9% (81/835)
# Epoch: 136 	Training Loss: 3.787292 	Validation Loss: 3.971924
#
# Test Accuracy:  8% (69/835)
# Epoch: 137 	Training Loss: 3.767817 	Validation Loss: 3.923718
# Validation loss decreased (3.924828 --> 3.923718).  Saving model ...
#
# Test Accuracy:  8% (75/835)
# Epoch: 138 	Training Loss: 3.779042 	Validation Loss: 3.926162
#
# Test Accuracy:  8% (74/835)
# Epoch: 139 	Training Loss: 3.760258 	Validation Loss: 3.922143
# Validation loss decreased (3.923718 --> 3.922143).  Saving model ...
#
# Test Accuracy:  9% (78/835)
# Epoch: 140 	Training Loss: 3.757817 	Validation Loss: 3.916343
# Validation loss decreased (3.922143 --> 3.916343).  Saving model ...
#
# Test Accuracy:  9% (80/835)
# Epoch: 141 	Training Loss: 3.763720 	Validation Loss: 3.957916
#
# Test Accuracy:  8% (71/835)
# Epoch: 142 	Training Loss: 3.756405 	Validation Loss: 3.897591
# Validation loss decreased (3.916343 --> 3.897591).  Saving model ...
#
# Test Accuracy: 10% (87/835)
# Epoch: 143 	Training Loss: 3.738357 	Validation Loss: 3.902784
#
# Test Accuracy:  9% (77/835)
# Epoch: 144 	Training Loss: 3.730622 	Validation Loss: 3.963146
#
# Test Accuracy:  9% (82/835)
# Epoch: 145 	Training Loss: 3.727312 	Validation Loss: 3.928789
#
# Test Accuracy:  9% (80/835)
# Epoch: 146 	Training Loss: 3.725379 	Validation Loss: 3.913482
#
# Test Accuracy: 10% (87/835)
# Epoch: 147 	Training Loss: 3.731282 	Validation Loss: 3.907604
#
# Test Accuracy:  9% (78/835)
# Epoch: 148 	Training Loss: 3.756378 	Validation Loss: 3.888823
# Validation loss decreased (3.897591 --> 3.888823).  Saving model ...
#
# Test Accuracy:  8% (74/835)
# Epoch: 149 	Training Loss: 3.714316 	Validation Loss: 3.933785
#
# Test Accuracy:  9% (82/835)
# Epoch: 150 	Training Loss: 3.699267 	Validation Loss: 3.916527
#
# Test Accuracy:  9% (78/835)

# %%
# load the model that got the best validation accuracy
if torch.cuda.is_available():
    model_scratch.load_state_dict(torch.load('model_scratch.pt'))
else:
    model_scratch.load_state_dict(torch.load('model_scratch.pt', map_location=lambda storage, loc: storage))

# %% [markdown]
# ### (IMPLEMENTATION) Test the Model
#
# Try out your model on the test dataset of dog images.  Use the code cell below to calculate and print the test loss and accuracy.  Ensure that your test accuracy is greater than 10%.

# %%
def test(loaders, model, criterion, use_cuda):

    # monitor test loss and accuracy
    test_loss = 0.
    correct = 0.
    total = 0.

    model.eval()
    for batch_idx, (data, target) in enumerate(loaders['test']):
        # move to GPU
        if use_cuda:
            data, target = data.cuda(), target.cuda()
        # forward pass: compute predicted outputs by passing inputs to the model
        output = model(data)
        # calculate the loss
        loss = criterion(output, target)
        # update average test loss 
        test_loss = test_loss + ((1 / (batch_idx + 1)) * (loss.data - test_loss))
        # convert output probabilities to predicted class
        pred = output.data.max(1, keepdim=True)[1]
        # compare predictions to true label
        correct += np.sum(np.squeeze(pred.eq(target.data.view_as(pred))).cpu().numpy())
        total += data.size(0)
            
    print('Test Loss: {:.6f}\n'.format(test_loss))

    print('\nTest Accuracy: %2d%% (%2d/%2d)' % (
        100. * correct / total, correct, total))

# %%
# call test function    
test(loaders_scratch, model_scratch, criterion_scratch, use_cuda)
# Out:
# Test Loss: 3.904009
#
#
# Test Accuracy:  8% (75/836)

# %% [markdown]
# ---
# <a id='step4'></a>
# ## Step 4: Create a CNN to Classify Dog Breeds (using Transfer Learning)
#
# You will now use transfer learning to create a CNN that can identify dog breed from images.  Your CNN must attain at least 60% accuracy on the test set.
#
# ### (IMPLEMENTATION) Specify Data Loaders for the Dog Dataset
#
# Use the code cell below to write three separate [data loaders](http://pytorch.org/docs/master/data.html#torch.utils.data.DataLoader) for the training, validation, and test datasets of dog images (located at `dogImages/train`, `dogImages/valid`, and `dogImages/test`, respectively).
#
# If you like, **you are welcome to use the same data loaders from the previous step**, when you created a CNN from scratch.

# %%
## DONE: Specify data loaders
## same data loaders from CNN from scratch
loaders_transfer = loaders_scratch

# %% [markdown]
# ### (IMPLEMENTATION) Model Architecture
#
# Use transfer learning to create a CNN to classify dog breed.  Use the code cell below, and save your initialized model as the variable `model_transfer`.

# %%
import torch.nn as nn
import torch.nn.functional as F

# define the CNN architecture
class Transfer_Net(nn.Module):
    ### TODO: choose an architecture, and complete the class
    def __init__(self):
        super(Transfer_Net, self).__init__()

        self.n_output = 133
        self.n_input = 25088
        
        self.fc1 = nn.Linear(self.n_input, 6272)
        self.fc2 = nn.Linear(6272, 3136)
        self.fc3 = nn.Linear(3136, 1568)
        self.fc4 = nn.Linear(1568, 784)
        self.fc5 = nn.Linear(784, self.n_output)
        self.dropout = nn.Dropout(0.4)
    
    def forward(self, x):

        # flatten image input
        x = x.view(x.shape[0], -1)
        
        x = self.dropout(F.relu(self.fc1(x)))
        x = self.dropout(F.relu(self.fc2(x)))
        x = self.dropout(F.relu(self.fc3(x)))
        x = self.dropout(F.relu(self.fc4(x)))
        x = F.log_softmax(self.fc5(x), dim=1)

        return x
    
    

#-#-# You so NOT have to modify the code below this line. #-#-#

# instantiate the CNN
model_transfer_net = Transfer_Net()

# %%
import torchvision.models as models
import torch.nn as nn


## DONE: Specify model architecture 
model_transfer = models.vgg16(pretrained=True)

for param in model_transfer.parameters():
        param.requires_grad = False

model_transfer.classifier = model_transfer_net

use_cuda = torch.cuda.is_available()


if use_cuda:
    model_transfer = model_transfer.cuda()

# %% [markdown]
# __Question 5:__ Outline the steps you took to get to your final CNN architecture and your reasoning at each step.  Describe why you think the architecture is suitable for the current problem.

# %% [markdown]
# __Answer:__

# %% [markdown]
# - I used the linear layers from my scratch model
# - I used the features that in pretrained model
# - I tested this model and I got good result i reach 61 at 11 Epoch

# %% [markdown]
# ### (IMPLEMENTATION) Specify Loss Function and Optimizer
#
# Use the next code cell to specify a [loss function](http://pytorch.org/docs/master/nn.html#loss-functions) and [optimizer](http://pytorch.org/docs/master/optim.html).  Save the chosen loss function as `criterion_transfer`, and the optimizer as `optimizer_transfer` below.

# %%
criterion_transfer = nn.NLLLoss()
optimizer_transfer = optim.Adam(model_transfer.classifier.parameters(), lr=0.00001)

# %% [markdown]
# ### (IMPLEMENTATION) Train and Validate the Model
#
# Train and validate your model in the code cell below.  [Save the final model parameters](http://pytorch.org/docs/master/notes/serialization.html) at filepath `'model_transfer.pt'`.

# %%
# train the model
n_epochs = 30
model_transfer = train(n_epochs, loaders_transfer, model_transfer, optimizer_transfer, criterion_transfer, use_cuda, 'model_transfer.pt')
# Out:
# Epoch: 1 	Training Loss: 4.870920 	Validation Loss: 4.813187
# Validation loss decreased (inf --> 4.813187).  Saving model ...
#
# Test Accuracy:  5% (45/835)
# Epoch: 2 	Training Loss: 4.736938 	Validation Loss: 4.444873
# Validation loss decreased (4.813187 --> 4.444873).  Saving model ...
#
# Test Accuracy: 10% (91/835)
# Epoch: 3 	Training Loss: 4.273016 	Validation Loss: 3.566365
# Validation loss decreased (4.444873 --> 3.566365).  Saving model ...
#
# Test Accuracy: 27% (226/835)
# Epoch: 4 	Training Loss: 3.598052 	Validation Loss: 2.788854
# Validation loss decreased (3.566365 --> 2.788854).  Saving model ...
#
# Test Accuracy: 39% (330/835)
# Epoch: 5 	Training Loss: 3.105304 	Validation Loss: 2.362079
# Validation loss decreased (2.788854 --> 2.362079).  Saving model ...
#
# Test Accuracy: 48% (404/835)
# Epoch: 6 	Training Loss: 2.735132 	Validation Loss: 2.022988
# Validation loss decreased (2.362079 --> 2.022988).  Saving model ...
#
# Test Accuracy: 51% (431/835)
# Epoch: 7 	Training Loss: 2.499430 	Validation Loss: 1.922067
# Validation loss decreased (2.022988 --> 1.922067).  Saving model ...
#
# Test Accuracy: 51% (433/835)
# Epoch: 8 	Training Loss: 2.299608 	Validation Loss: 1.666328
# Validation loss decreased (1.922067 --> 1.666328).  Saving model ...
#
# Test Accuracy: 57% (484/835)
# Epoch: 9 	Training Loss: 2.140524 	Validation Loss: 1.530169
# Validation loss decreased (1.666328 --> 1.530169).  Saving model ...
#
# Test Accuracy: 59% (499/835)
# Epoch: 10 	Training Loss: 2.010899 	Validation Loss: 1.457187
# Validation loss decreased (1.530169 --> 1.457187).  Saving model ...
#
# Test Accuracy: 62% (521/835)
# Epoch: 11 	Training Loss: 1.903873 	Validation Loss: 1.414776
# Validation loss decreased (1.457187 --> 1.414776).  Saving model ...
#
# Test Accuracy: 63% (529/835)
# Epoch: 12 	Training Loss: 1.801957 	Validation Loss: 1.375882
# Validation loss decreased (1.414776 --> 1.375882).  Saving model ...
#
# Test Accuracy: 64% (536/835)
# Epoch: 13 	Training Loss: 1.738796 	Validation Loss: 1.305214
# Validation loss decreased (1.375882 --> 1.305214).  Saving model ...
#
# Test Accuracy: 63% (534/835)
# Epoch: 14 	Training Loss: 1.644174 	Validation Loss: 1.232241
# Validation loss decreased (1.305214 --> 1.232241).  Saving model ...
#
# Test Accuracy: 67% (564/835)
# Epoch: 15 	Training Loss: 1.596502 	Validation Loss: 1.262912
#
# Test Accuracy: 65% (545/835)
# Epoch: 16 	Training Loss: 1.521857 	Validation Loss: 1.204112
# Validation loss decreased (1.232241 --> 1.204112).  Saving model ...
#
# Test Accuracy: 67% (564/835)
# Epoch: 17 	Training Loss: 1.479344 	Validation Loss: 1.145548
# Validation loss decreased (1.204112 --> 1.145548).  Saving model ...
#
# Test Accuracy: 67% (562/835)
# Epoch: 18 	Training Loss: 1.429776 	Validation Loss: 1.130790
# Validation loss decreased (1.145548 --> 1.130790).  Saving model ...
#
# Test Accuracy: 68% (575/835)
# Epoch: 19 	Training Loss: 1.372613 	Validation Loss: 1.165364
#
# Test Accuracy: 67% (566/835)
# Epoch: 20 	Training Loss: 1.332020 	Validation Loss: 1.112561
# Validation loss decreased (1.130790 --> 1.112561).  Saving model ...
#
# Test Accuracy: 69% (578/835)
# Epoch: 21 	Training Loss: 1.326591 	Validation Loss: 1.082505
# Validation loss decreased (1.112561 --> 1.082505).  Saving model ...
#
# Test Accuracy: 68% (576/835)
# Epoch: 22 	Training Loss: 1.313398 	Validation Loss: 1.049699
# Validation loss decreased (1.082505 --> 1.049699).  Saving model ...
#
# Test Accuracy: 70% (586/835)
# Epoch: 23 	Training Loss: 1.249245 	Validation Loss: 1.072692
#
# Test Accuracy: 69% (584/835)
# Epoch: 24 	Training Loss: 1.211484 	Validation Loss: 1.006010
# Validation loss decreased (1.049699 --> 1.006010).  Saving model ...
#
# Test Accuracy: 71% (598/835)
# Epoch: 25 	Training Loss: 1.203835 	Validation Loss: 1.065403
#
# Test Accuracy: 69% (584/835)
# Epoch: 26 	Training Loss: 1.187351 	Validation Loss: 0.987363
# Validation loss decreased (1.006010 --> 0.987363).  Saving model ...
#
# Test Accuracy: 71% (598/835)
# Epoch: 27 	Training Loss: 1.150271 	Validation Loss: 1.026325
#
# Test Accuracy: 70% (591/835)
# Epoch: 28 	Training Loss: 1.120189 	Validation Loss: 0.978894
# Validation loss decreased (0.987363 --> 0.978894).  Saving model ...
#
# Test Accuracy: 72% (604/835)
# Epoch: 29 	Training Loss: 1.080690 	Validation Loss: 1.015416
#
# Test Accuracy: 71% (595/835)
# Epoch: 30 	Training Loss: 1.106024 	Validation Loss: 0.939518
# Validation loss decreased (0.978894 --> 0.939518).  Saving model ...
#
# Test Accuracy: 74% (623/835)

# %%
# load the model that got the best validation accuracy (uncomment the line below)
if torch.cuda.is_available():
    model_transfer.load_state_dict(torch.load('model_transfer.pt'))
else:
    model_transfer.load_state_dict(torch.load('model_transfer.pt', map_location=lambda storage, loc: storage))

# %% [markdown]
# ### (IMPLEMENTATION) Test the Model
#
# Try out your model on the test dataset of dog images. Use the code cell below to calculate and print the test loss and accuracy.  Ensure that your test accuracy is greater than 60%.

# %%
test(loaders_transfer, model_transfer, criterion_transfer, use_cuda)
# Out:
# Test Loss: 1.032884
#
#
# Test Accuracy: 71% (598/836)

# %% [markdown]
# ### (IMPLEMENTATION) Predict Dog Breed with the Model
#
# Write a function that takes an image path as input and returns the dog breed (`Affenpinscher`, `Afghan hound`, etc) that is predicted by your model.

# %%
### DONE: Write a function that takes a path to an image as input
### and returns the dog breed that is predicted by the model.

# list of class names by index, i.e. a name can be accessed like class_names[0]
class_names = [item[4:].replace("_", " ") for item in image_datasets['train'].classes]

def predict_breed_transfer(img_path):
    # load the image and return the predicted breed
    image_tensor = load_image(img_path)
    display_image(image_tensor)

    if use_cuda:
        image_tensor = image_tensor.cuda()
        
    logps = model_transfer.forward(image_tensor.unsqueeze_(0))
    ps = torch.exp(logps)
    top_p, top_class = ps.topk(1, dim=1)
    
    return class_names[top_class[0].cpu().numpy()[0]]

# %%
def display_image(image):

    image = image.numpy()
    image = image.transpose((1, 2, 0))
    mean = np.array([0.485, 0.456, 0.406])
    std = np.array([0.229, 0.224, 0.225])
    image = std * image + mean

    image = np.clip(image, 0, 1)

    plt.imshow(image)
    plt.show()

# %% [markdown]
# ---
# <a id='step5'></a>
# ## Step 5: Write your Algorithm
#
# Write an algorithm that accepts a file path to an image and first determines whether the image contains a human, dog, or neither.  Then,
# - if a __dog__ is detected in the image, return the predicted breed.
# - if a __human__ is detected in the image, return the resembling dog breed.
# - if __neither__ is detected in the image, provide output that indicates an error.
#
# You are welcome to write your own functions for detecting humans and dogs in images, but feel free to use the `face_detector` and `human_detector` functions developed above.  You are __required__ to use your CNN from Step 4 to predict dog breed.
#
# Some sample output for our algorithm is provided below, but feel free to design your own user experience!
#
# ![Sample Human Output](images/sample_human_output.png)
#
#
# ### (IMPLEMENTATION) Write your Algorithm

# %%
### DONE: Write your algorithm.
### Feel free to use as many code cells as needed.

def run_app(img_path):
    ## handle cases for a human face, dog, and neither

    if dog_detector(img_path) :
        print('Hello ', predict_breed_transfer(img_path),' !')
        
    elif face_detector(img_path) :
        print('Hello human !')
        print('You look like :',predict_breed_transfer(img_path))
    else:
        print("The app only support human or dog images")
        
    print("-------------------------------\n")

# %% [markdown]
# ---
# <a id='step6'></a>
# ## Step 6: Test Your Algorithm
#
# In this section, you will take your new algorithm for a spin!  What kind of dog does the algorithm think that _you_ look like?  If you have a dog, does it predict your dog's breed accurately?  If you have a cat, does it mistakenly think that your cat is a dog?
#
# ### (IMPLEMENTATION) Test Your Algorithm on Sample Images!
#
# Test your algorithm at least six images on your computer.  Feel free to use any images you like.  Use at least two human and two dog images.
#
# __Question 6:__ Is the output better than you expected :) ?  Or worse :( ?  Provide at least three possible points of improvement for your algorithm.

# %% [markdown]
# __Answer:__ (Three possible points for improvement)

# %% [markdown]
# - predict diffrent kind of animals like cats
# - predict humans base on their country
# - make live prediction

# %%
## DONE: Execute your algorithm from Step 6 on
## at least 6 images on your computer.
## Feel free to use as many code cells as needed.

## suggested code, below
import numpy as np

for file in np.hstack((human_files[:3], dog_files[:3])):
    run_app(file)
# Out:
# Hello human !
# You look like : Basenji
# -------------------------------
#
# Hello human !
# You look like : Chesapeake bay retriever
# -------------------------------
# Hello  American water spaniel  !
# -------------------------------
# Hello  Belgian malinois  !
# -------------------------------
#
# The app only support human or dog images
# -------------------------------
# Hello  Bullmastiff  !
# -------------------------------
